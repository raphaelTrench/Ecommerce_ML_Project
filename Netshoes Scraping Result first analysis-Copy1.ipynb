# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns

# %% [markdown]
# # Carregando Dados

# %%
df_shoes = pd.read_csv('netshoes/netshoes.csv')
print(df_shoes.columns)
print(df_shoes.shape)
df_shoes.head()
# Out:
# Index(['brand', 'category', 'colors', 'customer_recommendation_rate',
#        'customer_reviews_number', 'customer_score', 'description', 'gender',
#        'image_urls', 'images', 'material', 'name', 'nationality', 'price',
#        'raw_name', 'tags', 'url', 'usage_type'],
#       dtype='object')
# (32194, 18)
#     brand       category          colors  customer_recommendation_rate  \
# 0  adidas         duramo    branco,cinza                          95.0
# 1  adidas         duramo    cinza,branco                          95.0
# 2  mizuno            NaN           preto                          97.0
# 3  adidas  amortecimento    preto,branco                          97.0
# 4  adidas         duramo  vermelho,preto                          95.0
#
#    customer_reviews_number  customer_score  \
# 0                     3633            4.48
# 1                     3633            4.48
# 2                      910            4.59
# 3                     1031            4.70
# 4                     3633            4.48
#
#                                          description     gender  \
# 0  Boa tênis de academia, o Adidas Duramo Lite 2 ...  masculino
# 1  Boa tênis de academia, o Adidas Duramo Lite 2 ...  masculino
# 2  Inspire-se para criar produções esportivas com...  masculino
# 3  Ideal para corredoras amadoras ou iniciantes, ...   feminino
# 4  Boa tênis de academia, o Adidas Duramo Lite 2 ...  masculino
#
#                                           image_urls  \
# 0  https://static.netshoes.com.br/produtos/tenis-...
# 1  https://static.netshoes.com.br/produtos/tenis-...
# 2  https://static.netshoes.com.br/produtos/tenis-...
# 3  https://static.netshoes.com.br/produtos/tenis-...
# 4  https://static.netshoes.com.br/produtos/tenis-...
#
#                                               images            material  \
# 0  COL-3586-158_zoom1.jpg,COL-3586-158_zoom2.jpg,...           sintético
# 1  COL-3586-226_zoom1.jpg,COL-3586-226_zoom2.jpg,...           sintético
# 2  D16-2255-006_zoom1.jpg,D16-2255-006_zoom2.jpg,...                mesh
# 3  COL-4395-026_zoom1.jpg,COL-4395-026_zoom2.jpg,...  sintético e têxtil
# 4  COL-3586-068_zoom1.jpg,COL-3586-068_zoom2.jpg,...           sintético
#
#                      name                                 nationality   price  \
# 0  adidas duramo lite 2 0  estrangeira - adquirida no mercado interno  164.99
# 1  adidas duramo lite 2 0                                    nacional  229.99
# 2          mizuno jet 3 n                                    nacional  159.99
# 3    adidas duramo lite 2                                    nacional  149.99
# 4  adidas duramo lite 2 0                                    nacional  149.99
#
#                                  raw_name  \
# 0  tênis adidas duramo lite 2 0 masculino
# 1  tênis adidas duramo lite 2 0 masculino
# 2          tênis mizuno jet 3 n masculino
# 3     tênis adidas duramo lite 2 feminino
# 4  tênis adidas duramo lite 2 0 masculino
#
#                                                 tags  \
# 0  branco,cinza,masculino,duramo,corrida,sintétic...
# 1  cinza,branco,masculino,duramo,corrida,sintétic...
# 2     preto,masculino,dia a dia,mesh,nacional,mizuno
# 3  preto,branco,feminino,amortecimento,dia a dia,...
# 4  vermelho,preto,masculino,duramo,corrida,sintét...
#
#                                                  url usage_type
# 0  https://www.netshoes.com.br/tenis-adidas-duram...    corrida
# 1  https://www.netshoes.com.br/tenis-adidas-duram...    corrida
# 2  https://www.netshoes.com.br/tenis-mizuno-jet-3...  dia a dia
# 3  https://www.netshoes.com.br/tenis-adidas-duram...  dia a dia
# 4  https://www.netshoes.com.br/tenis-adidas-duram...    corrida

# %%
df_shoes.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32194 entries, 0 to 32193
# Data columns (total 18 columns):
# brand                           32176 non-null object
# category                        9915 non-null object
# colors                          32194 non-null object
# customer_recommendation_rate    31738 non-null float64
# customer_reviews_number         32194 non-null int64
# customer_score                  32194 non-null float64
# description                     32111 non-null object
# gender                          32194 non-null object
# image_urls                      32194 non-null object
# images                          32194 non-null object
# material                        32194 non-null object
# name                            32194 non-null object
# nationality                     32194 non-null object
# price                           32194 non-null float64
# raw_name                        32194 non-null object
# tags                            32194 non-null object
# url                             32194 non-null object
# usage_type                      32194 non-null object
# dtypes: float64(3), int64(1), object(14)
# memory usage: 4.4+ MB

# %%
df_shoes.describe()
# Out:
#        customer_recommendation_rate  customer_reviews_number  customer_score  \
# count                  31738.000000             32194.000000    32194.000000
# mean                      93.448831               142.694136        4.472157
# std                        9.237133               410.714225        0.487010
# min                       50.000000                 1.000000        1.000000
# 25%                       91.000000                 6.000000        4.310000
# 50%                       96.000000                25.000000        4.570000
# 75%                      100.000000                92.000000        4.750000
# max                      100.000000              5411.000000        5.000000
#
#               price
# count  32194.000000
# mean     173.083840
# std      120.597483
# min       22.900000
# 25%       79.990000
# 50%      149.990000
# 75%      229.900000
# max     1299.990000

# %% [markdown]
# # Análise Exploratória
# ## Unique Values

# %%
for column in df_shoes.select_dtypes(exclude=["number"]).columns:
    print(f"{column}:")
    print(f"    {df_shoes[column].nunique()} valores únicos")
# Out:
# brand:
#     164 valores únicos
# category:
#     59 valores únicos
# colors:
#     493 valores únicos
# description:
#     3161 valores únicos
# gender:
#     5 valores únicos
# image_urls:
#     11710 valores únicos
# images:
#     11710 valores únicos
# material:
#     27 valores únicos
# name:
#     2702 valores únicos
# nationality:
#     6 valores únicos
# raw_name:
#     3037 valores únicos
# tags:
#     8324 valores únicos
# url:
#     11715 valores únicos
# usage_type:
#     8 valores únicos

# %% [markdown]
# # Análise Exploratória
# ## Análise Univariada
# ### Features Categóricas

# %%
def plot_value_counts(df,column,kind):
    if(kind == 'barh'):
        plt.figure(figsize=(10,25))
    else:
        plt.figure(figsize=(16,5))
    np.log(df[column].value_counts()).plot(kind=kind,title=f"{column}")
    plt.show()

# %%
plot_value_counts(df_shoes,'brand','barh')

# %%
old_shape = df_shoes.shape[0]
df_shoes = df_shoes[~df_shoes['raw_name'].str.contains('infantil')]
old_shape - df_shoes.shape[0]
# Out:
# 7226

# %%
plot_value_counts(df_shoes,'brand','barh')

# %%
plot_value_counts(df_shoes,'category','barh')

# %%
plot_value_counts(df_shoes,'gender','bar')

# %%
df_shoes.loc[df_shoes['gender']=='menino','gender'] = 'masculino'
df_shoes.loc[df_shoes['gender']=='menina','gender'] = 'feminino'

plot_value_counts(df_shoes,'gender','bar')

# %%
plot_value_counts(df_shoes,'material',kind='bar')

# %%
df_shoes.loc[df_shoes['material']=='sintético e couro','material'] = 'couro e sintético'
df_shoes.loc[df_shoes['material']=='sintético e têxtil','material'] = 'têxtil e sintético'
df_shoes.loc[df_shoes['material']=='couro e têxtil','material'] = 'têxtil e couro'

plot_value_counts(df_shoes,'material','bar')

# %%
plot_value_counts(df_shoes,'nationality','barh')

# %%
plot_value_counts(df_shoes,'usage_type','bar')

# %% [markdown]
# ## Features numéricas

# %%
for col in df_shoes.select_dtypes(include=['number']).columns:
    plt.figure(figsize=(15,6))
    plt.subplot(1, 2, 1)
    fig = sns.boxplot(y=df_shoes[col])
    fig.set_ylabel(col)
    fig.set_xlabel(col)
    
    plt.subplot(1, 2, 2)
    fig = sns.distplot(df_shoes[col].dropna())
    fig.set_xlabel(col)

    plt.show()

# %%
for col in df_shoes.select_dtypes(include=['number']).columns:
    plt.figure(figsize=(15,6))
    plt.subplot(1, 2, 1)
    fig = sns.boxplot(y=df_shoes[(df_shoes[col] > df_shoes[col].quantile(q=0.01)) &
                               (df_shoes[col] < df_shoes[col].quantile(q=0.99))][col])
        
    fig.set_ylabel(col)
    fig.set_xlabel(col)
    
    plt.subplot(1, 2, 2)
    fig = sns.distplot(df_shoes[(df_shoes[col] > df_shoes[col].quantile(q=0.01)) &
                               (df_shoes[col] < df_shoes[col].quantile(q=0.99))][col])
    fig.set_xlabel(col)

    plt.show()

# %%
colors = []
[[colors.append(color) for color in row.split(',')] for row in df_shoes['colors'].values]

counts = np.asarray(np.unique(colors,return_counts=True)).T
counts = pd.DataFrame(counts,columns=['color','count'])
counts['count'] = counts['count'].astype(float)
counts = counts.sort_values('count',ascending=False)

plt.figure(figsize=(16,10))
sns.barplot(x='color',y='count',data=counts)
plt.title("Frequências de cores")
plt.xticks(rotation=60)
plt.show()

# %%
largest_brands = df_shoes.groupby(['brand'])['brand'].count().nlargest(30)
plt.figure(figsize=(16,10))
plt.xticks(rotation=60)
plt.title("Marcas mais ocorrentes")
sns.barplot(x=largest_brands.index,y=largest_brands.values)

# %% [markdown]
# ## Análise Bivariada

# %%
df_shoes.columns
# Out:
# Index(['brand', 'category', 'colors', 'customer_recommendation_rate',
#        'customer_reviews_number', 'customer_score', 'description', 'gender',
#        'image_urls', 'images', 'material', 'name', 'nationality', 'price',
#        'raw_name', 'tags', 'url', 'usage_type'],
#       dtype='object')

# %%
def plot_ordered_by_y(x,y,data,rotation=50):
    ordered_axis = (data.groupby([x]).
                 agg({y : 'mean'}).
                 reset_index().sort_values(y,ascending=False)[x].values)

    sns.catplot(y=y,x=x,data=data, kind='bar', aspect=2,
                order=ordered_axis)
    plt.xticks(rotation=rotation)
    plt.title(f"{x.upper()} X {y.upper()}")
    plt.show()

# %%
plot_ordered_by_y('gender','price',df_shoes)

# %%
plot_ordered_by_y('material','price',df_shoes)

plot_ordered_by_y('material','customer_score',df_shoes[df_shoes['customer_reviews_number'] > 
                                                       df_shoes['customer_reviews_number'].quantile(0.1)])

# %%
groupby_name_score = df_shoes.groupby('name').agg({'customer_score' : 'mean', 'customer_reviews_number' : 'sum',
                                                   'customer_recommendation_rate' : 'mean',
                                                   'price' : 'mean'}).reset_index()
plot_ordered_by_y('name','customer_score',
                   groupby_name_score.loc[groupby_name_score.nlargest(20,'customer_reviews_number').index],
                  rotation=65)

plot_ordered_by_y('name','price',
                   groupby_name_score.loc[groupby_name_score.nlargest(20,'customer_reviews_number').index],
                  rotation=65)

plot_ordered_by_y('name','customer_recommendation_rate',
                   groupby_name_score.loc[groupby_name_score.nlargest(20,'customer_reviews_number').index],
                  rotation=65)

# %%
groupby_brand_score = df_shoes.groupby(['brand']).agg({'customer_score' : 'mean', 'customer_reviews_number' : 'sum',
                                                       'customer_recommendation_rate' : 'mean',
                                                       'price' : 'mean'}).reset_index()
plot_ordered_by_y('brand','customer_score',
                   groupby_brand_score.loc[groupby_brand_score.nlargest(20,'customer_reviews_number').index],
                  rotation=65)

plot_ordered_by_y('brand','price',
                   groupby_brand_score.loc[groupby_brand_score.nlargest(20,'customer_reviews_number').index],
                  rotation=65)

plot_ordered_by_y('brand','customer_recommendation_rate',
                   groupby_brand_score.loc[groupby_brand_score.nlargest(20,'customer_reviews_number').index],
                  rotation=65)

# %% [markdown]
# using pre selected brand names, infantil, couro
